# %%
import pandas
import seaborn as sns
from Bio import SeqIO
lengths = map(len, Bio.SeqIO.parse('/home/daria/Bioinf/python/biopython/amp_trimmed_1P', 'fastq'))
pandas.Series(lengths).hist(color='gray', bins=10)
# Out:
# <AxesSubplot:>
